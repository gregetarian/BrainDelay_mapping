# %%
#imports
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import brainspace as bs
from brainspace.gradient import diffusion_mapping

# %%
#setup key variables, set up color maps

goodROIs=[1, 5, 6, 7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 20, 21, 23, 24, 25, 26, 30, 31, 32, 33, 34, 36, 37, 38, 39, 40, 41, 42, 45, 46, 48, 49, 50, 52, 53, 54, 55, 56, 58, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 75, 76, 77, 78, 80, 82, 83, 84, 85, 86, 90, 91, 92, 94, 95, 96, 97, 98, 100, 101, 102, 103, 104, 105, 106, 110, 111, 112, 113, 114, 116, 117, 118, 120, 121, 122, 123, 124, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 140, 141, 142, 144, 147, 148, 149, 150, 152, 153, 154, 155, 156, 157, 158, 159, 161, 162, 163, 164, 165, 166, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 181, 183, 184, 185, 186, 188, 189, 191, 192, 195, 197, 199, 201, 202, 204, 205, 206, 209, 211, 212, 213, 214, 215, 216, 217, 218, 219, 221, 222, 223, 224, 225, 226, 229, 230, 231, 233, 234, 235, 237, 238, 239, 240, 242, 243, 244, 245, 246, 247, 249, 250, 251, 252, 253, 254, 255, 256, 257, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 271, 273, 274, 277, 279, 280, 281, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 311, 314, 315, 316, 317, 318, 319, 322, 323, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 342, 343, 344, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 360, 361, 362, 363, 365, 366, 367, 368, 369, 370, 372, 373, 374, 377, 379, 380, 381, 383, 385, 386, 387, 388, 389, 390, 391, 393, 394, 395, 396, 397, 398, 400, 401, 402, 405, 407, 408, 409, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 439, 441, 442, 443, 444, 445, 446, 447, 448, 449, 451, 452, 453, 456, 457, 458, 460, 461, 463, 464, 466, 467, 468, 470, 471, 472, 473, 474, 475, 476, 477, 480, 481, 482, 483, 484, 485, 486, 487, 488, 490, 492, 493, 494, 495, 496, 497, 499, 500, 502, 503, 504, 505, 506, 507, 508, 509, 510, 512, 513, 514, 515, 517, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 535, 539, 541, 542, 543, 544, 545, 548, 549, 550, 551, 552, 553, 555, 556, 557, 558, 559, 561, 564, 566, 567, 568, 571, 572, 573, 575, 576, 578, 581, 583, 584, 585, 588, 589, 590, 591, 592, 594, 596, 597, 598, 600, 602, 603, 604, 605, 606, 607, 608, 609, 611, 612, 614, 615, 616, 618, 620, 621, 623, 625, 626, 629, 631, 632, 633, 634, 635, 636, 638, 639, 641, 642, 644, 645, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 660, 662, 663, 665, 666, 667, 668, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 686, 689, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 703, 704, 707, 708, 709, 710, 711, 713, 714, 715, 716, 717, 718, 719, 720, 721, 722, 723, 724, 725, 726, 727, 728, 730, 731, 732, 734, 735, 736, 737, 738, 741, 742, 743, 745, 746, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 761, 762, 763, 764, 765, 766, 767, 768, 769, 771, 773, 774, 775, 776, 777, 778, 779, 780, 781, 783, 784, 786, 787, 788, 789, 790, 792, 793, 795, 796, 797, 798, 799, 801, 802, 803, 804, 806, 809, 810, 811, 813, 814, 815, 817, 818, 820, 821, 822, 823, 824, 825, 826, 827, 828, 830, 831, 832, 833, 834, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 854, 855, 856, 857, 858, 859, 860, 863, 864, 865, 866, 867, 868, 869, 870, 873, 874, 875, 877, 878, 879, 880, 881, 882, 883, 884, 885, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 901, 902, 903, 904, 905, 906, 907, 909, 910, 912, 913, 914, 915, 916, 918, 919, 920, 921, 923, 924, 925, 927, 928, 929, 930, 931, 932, 933, 934, 936, 937, 938, 939, 940, 941, 943, 944, 945, 946, 947, 951, 952, 954, 955, 956, 959, 960, 962, 963, 965, 966, 968, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1006, 1007, 1010, 1011, 1013, 1015, 1016, 1018, 1019, 1020, 1022, 1023]
print(len(goodROIs))

import pandas as pd
wdir='/Users/gcooper/Documents/DELAY_reanalysis/grp_avg/final_apc_attempt/'
wdir='/Users/gcooper/Desktop/Delay_attempt_9000/apc_post_fuckup/grp_avgs_download/apc_cluster_labels/' #old


# Create an empty dataframe to store the column names and file numbers
labels = pd.DataFrame(columns=['column_name', 'file_number'])

# Iterate over the text files

for i in range(1, 25):# old
    # Load the text file
    with open(wdir+'apc' + str(i) + '.txt', 'r') as f:
        # Extract the column names from the text file
        column_names = [line.strip() for line in f]
        # Add the column names and file numbers to the dataframe
        labels = labels.append(pd.DataFrame({'column_name': column_names, 'file_number': [i] * len(column_names)}))
#drop roi- from column names
labels['column_name'] = labels['column_name'].str.replace('roi-', '')
#str to int column names
labels['column_name'] = labels['column_name'].astype(int)

#sort by column name
labels=labels.sort_values(by=['column_name'])

display(labels)

#save labels[column_name] to list
labels_names = labels['column_name'].tolist()


#drop column name from labels
labels=labels.drop('column_name', axis=1)
display(labels)

cluster_labels=labels

#transpose labels
labels = labels.T

#to numpy
labels = labels.to_numpy()

import matplotlib 
import seaborn as sns

# Generate a 24-color colormap with maximum distinction between colors
colormap = sns.color_palette("gist_ncar", 24)#
# Visualize the colormap
sns.palplot(colormap)
custom_cmap = matplotlib.colors.ListedColormap(colormap)

overlap_cmap = sns.color_palette("gist_ncar", 10)#
sns.palplot(overlap_cmap)
print(overlap_cmap)

# %%
import pandas as pd
import numpy as np 
rois = [1, 5, 6, 7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 20, 21, 23, 24, 25, 26, 30, 31, 32, 33, 34, 36, 37, 38, 39, 40, 41, 42, 45, 46, 48, 49, 50, 52, 53, 54, 55, 56, 58, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 75, 76, 77, 78, 80, 82, 83, 84, 85, 86, 90, 91, 92, 94, 95, 96, 97, 98, 100, 101, 102, 103, 104, 105, 106, 110, 111, 112, 113, 114, 116, 117, 118, 120, 121, 122, 123, 124, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 140, 141, 142, 144, 147, 148, 149, 150, 152, 153, 154, 155, 156, 157, 158, 159, 161, 162, 163, 164, 165, 166, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 181, 183, 184, 185, 186, 188, 189, 191, 192, 195, 197, 199, 201, 202, 204, 205, 206, 209, 211, 212, 213, 214, 215, 216, 217, 218, 219, 221, 222, 223, 224, 225, 226, 229, 230, 231, 233, 234, 235, 237, 238, 239, 240, 242, 243, 244, 245, 246, 247, 249, 250, 251, 252, 253, 254, 255, 256, 257, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 271, 273, 274, 277, 279, 280, 281, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 311, 314, 315, 316, 317, 318, 319, 322, 323, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 342, 343, 344, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 360, 361, 362, 363, 365, 366, 367, 368, 369, 370, 372, 373, 374, 377, 379, 380, 381, 383, 385, 386, 387, 388, 389, 390, 391, 393, 394, 395, 396, 397, 398, 400, 401, 402, 405, 407, 408, 409, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 439, 441, 442, 443, 444, 445, 446, 447, 448, 449, 451, 452, 453, 456, 457, 458, 460, 461, 463, 464, 466, 467, 468, 470, 471, 472, 473, 474, 475, 476, 477, 480, 481, 482, 483, 484, 485, 486, 487, 488, 490, 492, 493, 494, 495, 496, 497, 499, 500, 502, 503, 504, 505, 506, 507, 508, 509, 510, 512, 513, 514, 515, 517, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 535, 539, 541, 542, 543, 544, 545, 548, 549, 550, 551, 552, 553, 555, 556, 557, 558, 559, 561, 564, 566, 567, 568, 571, 572, 573, 575, 576, 578, 581, 583, 584, 585, 588, 589, 590, 591, 592, 594, 596, 597, 598, 600, 602, 603, 604, 605, 606, 607, 608, 609, 611, 612, 614, 615, 616, 618, 620, 621, 623, 625, 626, 629, 631, 632, 633, 634, 635, 636, 638, 639, 641, 642, 644, 645, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 660, 662, 663, 665, 666, 667, 668, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 686, 689, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 703, 704, 707, 708, 709, 710, 711, 713, 714, 715, 716, 717, 718, 719, 720, 721, 722, 723, 724, 725, 726, 727, 728, 730, 731, 732, 734, 735, 736, 737, 738, 741, 742, 743, 745, 746, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 761, 762, 763, 764, 765, 766, 767, 768, 769, 771, 773, 774, 775, 776, 777, 778, 779, 780, 781, 783, 784, 786, 787, 788, 789, 790, 792, 793, 795, 796, 797, 798, 799, 801, 802, 803, 804, 806, 809, 810, 811, 813, 814, 815, 817, 818, 820, 821, 822, 823, 824, 825, 826, 827, 828, 830, 831, 832, 833, 834, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 854, 855, 856, 857, 858, 859, 860, 863, 864, 865, 866, 867, 868, 869, 870, 873, 874, 875, 877, 878, 879, 880, 881, 882, 883, 884, 885, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 901, 902, 903, 904, 905, 906, 907, 909, 910, 912, 913, 914, 915, 916, 918, 919, 920, 921, 923, 924, 925, 927, 928, 929, 930, 931, 932, 933, 934, 936, 937, 938, 939, 940, 941, 943, 944, 945, 946, 947, 951, 952, 954, 955, 956, 959, 960, 962, 963, 965, 966, 968, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1006, 1007, 1010, 1011, 1013, 1015, 1016, 1018, 1019, 1020, 1022, 1023]  # Add the remaining roi numbers here
dfs = []

for roi in rois:
    df=pd.read_csv("/Users/gcooper/Downloads/delay_graphs/1d_dumps/"f"inputs_to_roi-{roi}.1D", sep=" ", usecols=[0], header=None)
    dfs.append(df)

result_delays=pd.concat(dfs, axis=1)


#set column and index names to match roi names
result_delays.columns = rois
result_delays.index = rois
np.fill_diagonal(result_delays.values, 0)
display(result_delays)

result_delays.to_csv("/Users/gcooper/Documents/delay_model/delay_matrix.csv")

import pandas as pd
import numpy as np 
rois = [1, 5, 6, 7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 20, 21, 23, 24, 25, 26, 30, 31, 32, 33, 34, 36, 37, 38, 39, 40, 41, 42, 45, 46, 48, 49, 50, 52, 53, 54, 55, 56, 58, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 73, 75, 76, 77, 78, 80, 82, 83, 84, 85, 86, 90, 91, 92, 94, 95, 96, 97, 98, 100, 101, 102, 103, 104, 105, 106, 110, 111, 112, 113, 114, 116, 117, 118, 120, 121, 122, 123, 124, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 140, 141, 142, 144, 147, 148, 149, 150, 152, 153, 154, 155, 156, 157, 158, 159, 161, 162, 163, 164, 165, 166, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 181, 183, 184, 185, 186, 188, 189, 191, 192, 195, 197, 199, 201, 202, 204, 205, 206, 209, 211, 212, 213, 214, 215, 216, 217, 218, 219, 221, 222, 223, 224, 225, 226, 229, 230, 231, 233, 234, 235, 237, 238, 239, 240, 242, 243, 244, 245, 246, 247, 249, 250, 251, 252, 253, 254, 255, 256, 257, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 271, 273, 274, 277, 279, 280, 281, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 311, 314, 315, 316, 317, 318, 319, 322, 323, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 342, 343, 344, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 360, 361, 362, 363, 365, 366, 367, 368, 369, 370, 372, 373, 374, 377, 379, 380, 381, 383, 385, 386, 387, 388, 389, 390, 391, 393, 394, 395, 396, 397, 398, 400, 401, 402, 405, 407, 408, 409, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 439, 441, 442, 443, 444, 445, 446, 447, 448, 449, 451, 452, 453, 456, 457, 458, 460, 461, 463, 464, 466, 467, 468, 470, 471, 472, 473, 474, 475, 476, 477, 480, 481, 482, 483, 484, 485, 486, 487, 488, 490, 492, 493, 494, 495, 496, 497, 499, 500, 502, 503, 504, 505, 506, 507, 508, 509, 510, 512, 513, 514, 515, 517, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 535, 539, 541, 542, 543, 544, 545, 548, 549, 550, 551, 552, 553, 555, 556, 557, 558, 559, 561, 564, 566, 567, 568, 571, 572, 573, 575, 576, 578, 581, 583, 584, 585, 588, 589, 590, 591, 592, 594, 596, 597, 598, 600, 602, 603, 604, 605, 606, 607, 608, 609, 611, 612, 614, 615, 616, 618, 620, 621, 623, 625, 626, 629, 631, 632, 633, 634, 635, 636, 638, 639, 641, 642, 644, 645, 646, 647, 648, 649, 650, 651, 652, 653, 654, 655, 656, 657, 660, 662, 663, 665, 666, 667, 668, 670, 671, 672, 673, 674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 686, 689, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 703, 704, 707, 708, 709, 710, 711, 713, 714, 715, 716, 717, 718, 719, 720, 721, 722, 723, 724, 725, 726, 727, 728, 730, 731, 732, 734, 735, 736, 737, 738, 741, 742, 743, 745, 746, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 761, 762, 763, 764, 765, 766, 767, 768, 769, 771, 773, 774, 775, 776, 777, 778, 779, 780, 781, 783, 784, 786, 787, 788, 789, 790, 792, 793, 795, 796, 797, 798, 799, 801, 802, 803, 804, 806, 809, 810, 811, 813, 814, 815, 817, 818, 820, 821, 822, 823, 824, 825, 826, 827, 828, 830, 831, 832, 833, 834, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 854, 855, 856, 857, 858, 859, 860, 863, 864, 865, 866, 867, 868, 869, 870, 873, 874, 875, 877, 878, 879, 880, 881, 882, 883, 884, 885, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 901, 902, 903, 904, 905, 906, 907, 909, 910, 912, 913, 914, 915, 916, 918, 919, 920, 921, 923, 924, 925, 927, 928, 929, 930, 931, 932, 933, 934, 936, 937, 938, 939, 940, 941, 943, 944, 945, 946, 947, 951, 952, 954, 955, 956, 959, 960, 962, 963, 965, 966, 968, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1006, 1007, 1010, 1011, 1013, 1015, 1016, 1018, 1019, 1020, 1022, 1023]  # Add the remaining roi numbers here

dfs = []

for roi in rois:
    df = pd.read_csv("/Users/gcooper/Downloads/coef_maskaves/"f"roi-{roi}.1D", sep=" ", header=None, usecols=[0])
    dfs.append(df)

result = pd.concat(dfs, axis=1)
result.to_csv("/Users/gcooper/Downloads/delay_graphs/concatenated_columns_new.csv", index=False, header=False)
result.to_csv("/Users/gcooper/Documents/delay_model/conn_matrix.csv", index=False, header=False)


#set column and index names to match roi names
result.columns = rois
result.index = rois
np.fill_diagonal(result.values, 0)
display(result)

####
# THIS ONE IS FOR INPUTS
# 
# 
# #import corr coeff array, run diffusion embedding 
X=result.values
#normalise X
from sklearn.preprocessing import normalize
X = normalize(X)
X=X.T # transposition meaning cosine similarity is calculated across colums. Thus, these represent INPUT gradients.
print(X.shape)
#import brainspace
from brainspace.gradient.gradient import GradientMaps
gm=GradientMaps(n_components=10, kernel='cosine', random_state=0)
gm.fit(X, sparsity=0.95)



import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['font.family'] = 'Latin Modern Roman'
#plot lamdas, save XYZ embedding coordinates 
fig, ax = plt.subplots(1, figsize=(5, 4))
ax.scatter(range(gm.lambdas_.size), gm.lambdas_)
ax.set_xlabel('Component Nb')
ax.set_ylabel('Eigenvalue')

plt.show()


#save gm.gradients_[:,0], gm.gradients_[:,1], gm.gradients_[:,2] to list called xyz
x = gm.gradients_[:, 0]
y = gm.gradients_[:, 1]
z = gm.gradients_[:, 2]
a = gm.gradients_[:, 3]
b = gm.gradients_[:, 4]

x = pd.DataFrame(x, columns=['x'])
y = pd.DataFrame(y, columns=['y'])
z = pd.DataFrame(z, columns=['z'])
a = pd.DataFrame(a, columns=['a'])
b = pd.DataFrame(b, columns=['b'])

xyz_diffusion = pd.concat([x, y, z, a, b], axis=1)

#add labels for plotting
xyz_diffusion['labels'] = rois
display(xyz_diffusion)
#save xyz to csv
xyz_diffusion.to_csv('/Users/gcooper/Desktop/Delay_attempt_9000/pca/xyza_coef_INPUTS_diffusion_final.csv', index=False)


import seaborn as sns
import matplotlib.pyplot as plt


import numpy as np

import matplotlib as mpl
import matplotlib.cm as cm

# Convert first three dimensions of gm.gradients_ to a DataFrame
df = pd.DataFrame(gm.gradients_[:,:3], columns=['x', 'y', 'z'])

# Normalize and apply colormap for each dimension
norm_x = mpl.colors.Normalize(vmin=df['x'].min(), vmax=df['x'].max())
norm_y = mpl.colors.Normalize(vmin=df['y'].min(), vmax=df['y'].max())
norm_z = mpl.colors.Normalize(vmin=df['z'].min(), vmax=df['z'].max())

cmap_x = cm.Reds
cmap_y = cm.Greens
cmap_z = cm.Blues


# cmap_x = cm.Blues
# cmap_y = cm.Reds
# cmap_z = cm.Greens

map_x = cm.ScalarMappable(norm=norm_x, cmap=cmap_x)
map_y = cm.ScalarMappable(norm=norm_y, cmap=cmap_y)
map_z = cm.ScalarMappable(norm=norm_z, cmap=cmap_z)

# Create an array for the colors
c = np.ones(map_x.to_rgba(df['x']).shape)

# Modify the green and blue channels based on 'x'
c[:,1] = df['y'] - df['y'].min()
c[:,1] /= c[:,1].max()

c[:,2] = (df['z'] * -1) - (df['z'] * -1).min()
c[:,2] /= c[:,2].max()

c[:,0] = df['x'] - df['x'].min()
c[:,0] /= c[:,0].max()

c[:,1] = c[:,1] * ((c[:,0] - 1) * -1)
c[:,2] = c[:,2] * ((c[:,0] - 1) * -1)

# Convert to hex for Plotly
hex_colors = ['#%02x%02x%02x' % (int(r), int(g), int(b)) for r, g, b in c[:, :3]*255]


# Set the context for the plot
sns.set_context("paper", font_scale=2)
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Latin Modern Roman'

fig, ax = plt.subplots(figsize=(10, 10))

# Create the scatter plot
sc = ax.scatter(df['x'], df['y'], c=np.array(c), alpha=0.8)

# Set the labels for the axes
ax.set_xlabel('Gradient 1')
ax.set_ylabel('Gradient 2')

# Set the limits for the axes
ax.set_xlim([np.min(df['x']) - 0.5, np.max(df['x']) + 0.5])
ax.set_ylim([np.min(df['y']) - 0.5, np.max(df['y']) + 0.5])

# Show the plot
plt.show()

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111, projection='3d')

# Set the background color to transparent
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.w_xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.w_yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.w_zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))

# Create the 3D scatter plot
sc = ax.scatter(df['x'], df['y'], df['z'], c=np.array(c), alpha=0.8)

# Set the limits for the axes
ax.set_xlim([np.min(df['x']) - 0.5, np.max(df['x']) + 0.5])
ax.set_ylim([np.min(df['y']) - 0.5, np.max(df['y']) + 0.5])
ax.set_zlim([np.min(df['z']) - 0.5, np.max(df['z']) + 0.5])


#save with transparent background
plt.savefig('/Users/gcooper/Desktop/Delay_attempt_9000/pca/xyza_coef_INPUTS_diffusion_final_transparent.png', transparent=True)

# Show the plot
plt.show()
